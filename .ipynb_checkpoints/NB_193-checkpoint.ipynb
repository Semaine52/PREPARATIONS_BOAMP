# %% [markdown]
# # Notebook #193

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Semaine52/BOAMP_2022_CSV/main/df_boamp_2022_01_D_01_identite_A.csv')

# %%
df.set_index("BOAMP_AVIS_NUM", inplace=True, drop=True )

# %%
df = df.loc[:, ["D_01_01_Identite_Denomination"]]

# %%
df
# Out:
#                        D_01_01_Identite_Denomination
# BOAMP_AVIS_NUM
# 21-114011                      Ville d'Aubervilliers
# 21-114252                        Université de Corse
# 21-129515                          MINARM/DGA/DO/S2A
# 21-129881          Centre HOSPITALIER DE SAINT DENIS
# 21-129904                             CNRS Marseille
# ...                                              ...
# 22-1997                                       SYTRAL
# 22-200             Conseil général de la Haute-Marne
# 22-2003                                       CCPFML
# 22-2004                Mairie de Canet en Roussillon
# 22-2014         Communauté Communes Parthenay-Gâtine
#
# [1282 rows x 1 columns]
