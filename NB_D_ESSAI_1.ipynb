# %% [markdown]
# # Notebook d'essai #1

# %%
import pandas as pd

# %%
df_ = pd.read_csv('http://www.aufilduboamp.com/DOCS/BOAMP_MOIS_CSV/df_boamp_2022_01_D_01_identite.csv')

# %%
df_
# Out:
#      BOAMP_AVIS_NUM          D_01_01_Identite_Denomination  \
# 0         21-114011                  Ville d'Aubervilliers
# 1         21-114252                    Université de Corse
# 2         21-129515                      MINARM/DGA/DO/S2A
# 3         21-129881      Centre HOSPITALIER DE SAINT DENIS
# 4         21-129904                         CNRS Marseille
# ...             ...                                    ...
# 1961        22-9967    COLLECTIVITE TERRITORIALE DE GUYANE
# 1962        22-9968                                SPL OPE
# 1963        22-9976  OFFICE PUB DE L HABITAT HTES PYRENEES
# 1964        22-9978           Conseil Départemental du Var
# 1965        22-9981                      COMMUNE D OYONNAX
#
#      D_01_02_Identite_Codeidentnational  \
# 0                                  None
# 1                                  None
# 2                    FR5415200046900014
# 3                                  None
# 4                                  None
# ...

# %%
df2_ = pd.read_csv('https://raw.githubusercontent.com/Semaine52/BOAMP_2022_CSV/main/df_boamp_2022_01_D_02_typeorganisme_A.csv')

# %%
df2_
# Out:
#     BOAMP_AVIS_NUM  D_02_01_Typeorganisme_Institutioneuropeenne  \
# 0        21-129881                                        False
# 1        21-129904                                        False
# 2        21-136532                                        False
# 3        21-145277                                        False
# 4        21-152676                                        False
# ..             ...                                          ...
# 698        22-4917                                        False
# 699        22-4924                                        False
# 700        22-4934                                        False
# 701        22-4940                                        False
# 702        22-4941                                        False
#
#      D_02_02_Typeorganisme_Etat  D_02_03_Typeorganisme_Region  \
# 0                         False                         False
# 1                         False                         False
# ...
